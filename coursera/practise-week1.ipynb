# %%
import csv

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('coursera.csv')

# %%
df.describe()
# Out:
#                HHID          TIME         PASTA         EXPOS           AGE  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean    1000.500000     10.500000      1.841545      0.499100     42.251409
# std      577.357414      5.766353      1.025911      0.702041     13.766646
# min        1.000000      1.000000      0.000000      0.000000     18.007529
# 25%      500.750000      5.750000      1.108936      0.000000     30.505706
# 50%     1000.500000     10.500000      1.811417      0.000000     42.436092
# 75%     1500.250000     15.250000      2.534365      1.000000     54.362395
# max     2000.000000     20.000000      6.592769      5.000000     64.984126
#
#               INCOME          AREA
# count   40000.000000  40000.000000
# mean    27096.126112      2.996000
# std     15928.188291      1.409622
# min       609.107170      1.000000
# 25%     15379.591862      2.000000
# 50%     24487.068020      3.000000
# ...

# %%
df
# Out:
#        HHID  TIME     PASTA  EXPOS        AGE        INCOME  AREA
# 0         1     1  0.939444      1  61.710758  25186.798772     3
# 1         1     2  2.560969      2  61.710758  25186.798772     3
# 2         1     3  0.901123      0  61.710758  25186.798772     3
# 3         1     4  1.916530      1  61.710758  25186.798772     3
# 4         1     5  1.548751      0  61.710758  25186.798772     3
# 5         1     6  2.169405      0  61.710758  25186.798772     3
# 6         1     7  2.804702      0  61.710758  25186.798772     3
# 7         1     8  2.288013      0  61.710758  25186.798772     3
# 8         1     9  2.263326      0  61.710758  25186.798772     3
# 9         1    10  1.357010      1  61.710758  25186.798772     3
# 10        1    11  1.880099      1  61.710758  25186.798772     3
# 11        1    12  2.305813      0  61.710758  25186.798772     3
# 12        1    13  1.104250      0  61.710758  25186.798772     3
# ...

# %%
df.groupby('AREA')['INCOME'].describe()
# Out:
#        count          mean           std          min           25%  \
# AREA
# 1     7960.0  28076.599968  15992.263390  2740.776521  15229.286699
# 2     8060.0  26218.857948  15214.877592   609.107170  15747.651774
# 3     8040.0  25879.485698  15388.072287  2353.176959  15278.278474
# 4     8060.0  29260.133137  16280.430895  1241.960729  16501.072967
# 5     7880.0  26030.910606  16460.597663  1331.260222  14015.559944
#
#                50%           75%            max
# AREA
# 1     25370.030640  37809.618971   85241.329860
# 2     23381.224414  32624.672106  106319.106367
# 3     23596.900315  32880.445859  111295.840727
# 4     26499.489701  39052.695544  112983.969631
# 5     23135.644593  34609.407340  141066.966883

# %%
df.groupby('AREA')['HHID'].describe()
# Out:
#        count         mean         std   min    25%     50%     75%     max
# AREA
# 1     7960.0   957.695980  587.956060   4.0  431.0   942.5  1473.0  1998.0
# 2     8060.0   983.397022  580.693187  10.0  501.0   974.0  1480.0  1999.0
# 3     8040.0  1002.012438  579.367532   1.0  487.0   982.0  1509.0  2000.0
# 4     8060.0  1068.101737  554.521974   3.0  614.0  1100.0  1547.0  1997.0
# 5     7880.0   990.543147  578.119178   5.0  478.0   996.5  1522.0  1995.0

# %%
p = df.groupby('HHID')['PASTA']

# %%
s = p.sum()

# %%
max(s)
# Out:
# 55.36193058243068

# %%
df[(df.AREA ==2) & (df.INCOME > 20000)].count()
# Out:
# HHID      4880
# TIME      4880
# PASTA     4880
# EXPOS     4880
# AGE       4880
# INCOME    4880
# AREA      4880
# dtype: int64

# %%
ex = df[(df.AREA ==2) & (df.INCOME > 20000)].groupby('HHID')['PASTA'].sum()

# %%
ex[ex>30].count()
# Out:
# 218

# %%
df['PASTA'].corr(df['EXPOS'])
# Out:
# 0.32661737731864954

# %%
p = df.groupby('TIME')['PASTA'].sum()

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(p)

# %%
p
# Out:
# TIME
# 1     3705.741158
# 2     3599.028148
# 3     3699.517762
# 4     3612.204636
# 5     3760.695910
# 6     3668.275370
# 7     3702.510261
# 8     3677.773211
# 9     3648.582796
# 10    3728.283701
# 11    3694.632177
# 12    3612.470725
# 13    3717.297217
# 14    3577.707839
# 15    3713.876670
# 16    3665.214265
# 17    3791.081083
# 18    3695.177017
# 19    3708.959742
# 20    3682.751853
# Name: PASTA, dtype: float64
